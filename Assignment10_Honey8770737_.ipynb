# %%
#2.a
"""import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')
# Step 2: Overview of the dataset
print("Data Overview:")
print(df.info())

# Step 3: Summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Step 4: Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Step 5: Check unique values in categorical columns
categorical_columns = ['positionText', 'fastestLaptime']
for col in categorical_columns:
    print(f"\nUnique values in {col}:")
    print(df[col].unique())

# Step 6: Distribution of numeric features
numeric_features = ['grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_features, 1):
    plt.subplot(3, 4, i)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# Step 7: Correlation between numeric features
correlation_matrix = df[numeric_features].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation between Numeric Features")
plt.show()

# Step 8: Distribution of positionText
plt.figure(figsize=(10, 6))
sns.countplot(x='positionText', data=df)
plt.title("Distribution of Position Text")
plt.xlabel("Position Text")
plt.ylabel("Count")
plt.show()

# Step 9: Distribution of fastestLaptime
plt.figure(figsize=(10, 6))
sns.histplot(df['fastestLaptime'], kde=True)
plt.title("Distribution of Fastest Lap Time")
plt.xlabel("Fastest Lap Time")
plt.show()

# Step 10: Box plot of position vs. points
plt.figure(figsize=(10, 6))
sns.boxplot(x='position', y='points', data=df)
plt.title("Position vs. Points")
plt.xlabel("Position")
plt.ylabel("Points")
plt.show()

# Step 11: Pair plot of selected numeric features
selected_features = ['grid', 'position', 'points', 'laps', 'milliseconds', 'fastestLap']
sns.pairplot(df[selected_features], diag_kind='kde')
plt.suptitle("Pair Plot of Selected Numeric Features", y=1.02)
plt.show()"""

#2.b 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')

# Step 2: Overview of the dataset
print("Data Overview:")
print(df.info())

# Step 3: Summary statistics
print("\nSummary Statistics:")
print(df.describe())

# Step 4: Identify data types
print("\nData Types:")
print(df.dtypes)

# Step 5: Visualize the data distribution
plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='position', kde=True, bins=20)
plt.title("Distribution of Positions")
plt.xlabel("Position")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='points', kde=True, bins=20)
plt.title("Distribution of Points")
plt.xlabel("Points")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='fastestLap', kde=True, bins=20)
plt.title("Distribution of Fastest Laps")
plt.xlabel("Fastest Lap")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='rank', kde=True, bins=20)
plt.title("Distribution of Ranks")
plt.xlabel("Rank")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='fastestLapSpeed', kde=True, bins=20)
plt.title("Distribution of Fastest Lap Speeds")
plt.xlabel("Fastest Lap Speed")
plt.ylabel("Count")
plt.show()

# Step 6: Correlation between numeric features
numeric_features = ['grid', 'position', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
correlation_matrix = df[numeric_features].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation between Numeric Features")
plt.show()

# Step 7: Pair plot of selected numeric features
selected_features = ['grid', 'position', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed']
sns.pairplot(df[selected_features], diag_kind='kde')
plt.suptitle("Pair Plot of Selected Numeric Features", y=1.02)
plt.show()


"""#3.a
import pandas as pd

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')
# Step 2: Handle missing values in the entire DataFrame
df.replace('\\N', pd.NA, inplace=True)

# Step 3: Convert relevant columns to numeric
numeric_columns = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 4: Handle missing values in the 'rank' column
median_rank = df['rank'].median()
df['rank'].fillna(median_rank, inplace=True)

# Step 5: Explore the preprocessed data (optional)
print(df.head())

# Step 6: Save the preprocessed data to a new CSV file (optional)
preprocessed_dataset_path = 'preprocessed_results.csv'
df.to_csv(preprocessed_dataset_path, index=False)"""

"""#3.b 

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')
# Step 2: Handle missing values
df.replace('\\N', np.nan, inplace=True)

# Step 3: Convert relevant columns to numeric
numeric_columns = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 4: Handle missing values in the 'rank' column
median_rank = df['rank'].median()
df['rank'].fillna(median_rank, inplace=True)

# Step 5: Handle outliers (optional)
Q1 = df['position'].quantile(0.25)
Q3 = df['position'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
df = df[df['position'] <= upper_bound]

# Step 6: Feature Engineering (optional)
df['race_length'] = df['laps'] * df['milliseconds']

# Step 7: Prepare the data for machine learning
X = df[['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'fastestLapSpeed', 'statusId', 'race_length']]
y = df['rank']

# Step 8: Handle missing values in the features (X)
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Step 9: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Step 10: Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 11: Train and evaluate machine learning models on the preprocessed data

# Train a Support Vector Machine (SVM) classifier
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
svm_predictions = svm_model.predict(X_test_scaled)

# Evaluate the SVM model
print("Support Vector Machine (SVM) Accuracy:", accuracy_score(y_test, svm_predictions))
print("Support Vector Machine (SVM) Classification Report:")
print(classification_report(y_test, svm_predictions))
"""

"""#4.a

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')
# Step 2: Handle missing values
df.replace('\\N', np.nan, inplace=True)

# Step 3: Convert relevant columns to numeric
numeric_columns = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 4: Handle missing values in the 'rank' column
median_rank = df['rank'].median()
df['rank'].fillna(median_rank, inplace=True)

# Step 5: Handle outliers (optional)
Q1 = df['position'].quantile(0.25)
Q3 = df['position'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
df = df[df['position'] <= upper_bound]

# Step 6: Feature Engineering (optional)
df['race_length'] = df['laps'] * df['milliseconds']

# Step 7: Prepare the data for machine learning
X = df[['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'fastestLapSpeed', 'statusId', 'race_length']]
y = df['rank']

# Step 8: Handle missing values in the features (X)
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Step 9: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Step 10: Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 11: Implement Machine Learning Models

# Model 1: Support Vector Machine (SVM)
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
svm_predictions = svm_model.predict(X_test_scaled)

# Model 2: Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)
rf_predictions = rf_model.predict(X_test_scaled)

# Step 12: Evaluate the models
print("Support Vector Machine (SVM) Accuracy:", accuracy_score(y_test, svm_predictions))
print("Support Vector Machine (SVM) Classification Report:")
print(classification_report(y_test, svm_predictions))

print("\nRandom Forest Accuracy:", accuracy_score(y_test, rf_predictions))
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_predictions))"""

"""#4.b
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')
# Step 2: Handle missing values
df.replace('\\N', np.nan, inplace=True)

# Step 3: Convert relevant columns to numeric
numeric_columns = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 4: Handle missing values in the 'rank' column
median_rank = df['rank'].median()
df['rank'].fillna(median_rank, inplace=True)

# Step 5: Handle outliers (optional)
Q1 = df['position'].quantile(0.25)
Q3 = df['position'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
df = df[df['position'] <= upper_bound]

# Step 6: Feature Engineering (optional)
df['race_length'] = df['laps'] * df['milliseconds']

# Step 7: Prepare the data for machine learning
X = df[['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'fastestLapSpeed', 'statusId', 'race_length']]
y = df['rank']

# Step 8: Handle missing values in the features (X)
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Step 9: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

# Step 10: Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 11: Implement Machine Learning Models

# Model 1: Support Vector Machine (SVM)
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
svm_predictions = svm_model.predict(X_test_scaled)

# Model 2: Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)
rf_predictions = rf_model.predict(X_test_scaled)

# Step 12: Evaluate the models
print("Support Vector Machine (SVM) Accuracy:", accuracy_score(y_test, svm_predictions))
print("Support Vector Machine (SVM) Precision:", precision_score(y_test, svm_predictions, average='macro'))
print("Support Vector Machine (SVM) Recall:", recall_score(y_test, svm_predictions, average='macro'))
print("Support Vector Machine (SVM) F1-score:", f1_score(y_test, svm_predictions, average='macro'))
print("Support Vector Machine (SVM) Classification Report:")
print(classification_report(y_test, svm_predictions))

print("\nRandom Forest Accuracy:", accuracy_score(y_test, rf_predictions))
print("Random Forest Precision:", precision_score(y_test, rf_predictions, average='macro'))
print("Random Forest Recall:", recall_score(y_test, rf_predictions, average='macro'))
print("Random Forest F1-score:", f1_score(y_test, rf_predictions, average='macro'))
print("Random Forest Classification Report:")
print(classification_report(y_test, rf_predictions))"""

"""#5.a 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')

# Step 2: Handle missing values
df.replace('\\N', np.nan, inplace=True)

# Step 3: Convert relevant columns to numeric
numeric_columns = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 4: Handle missing values in the 'rank' column
median_rank = df['rank'].median()
df['rank'].fillna(median_rank, inplace=True)

# Step 5: Handle outliers (optional)
Q1 = df['position'].quantile(0.25)
Q3 = df['position'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
df = df[df['position'] <= upper_bound]

# Step 6: Feature Engineering (optional)
df['race_length'] = df['laps'] * df['milliseconds']

# Step 7: Create meaningful visualizations

# Scatter Plot: Relationship between 'position' and 'race_length'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='position', y='race_length', data=df)
plt.title("Scatter Plot: Position vs. Race Length")
plt.xlabel("Position")
plt.ylabel("Race Length")
plt.show()

# Heatmap: Correlation between numeric features
numeric_features = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId', 'race_length']
correlation_matrix = df[numeric_features].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Heatmap: Correlation between Numeric Features")
plt.show()

# Bar Chart: Number of drivers by constructor
plt.figure(figsize=(12, 6))
driver_count_by_constructor = df.groupby('constructorId')['driverId'].nunique().reset_index()
sns.barplot(x='constructorId', y='driverId', data=driver_count_by_constructor)
plt.title("Number of Drivers by Constructor")
plt.xlabel("Constructor ID")
plt.ylabel("Number of Drivers")
plt.show()

# Bar Chart: Distribution of positions
plt.figure(figsize=(10, 6))
sns.countplot(x='position', data=df)
plt"""


"""#5.b 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('E:\\HONEY\\Conestoga\\BIGDATA_SOLUTION_ARCHITECTURE\\ProgforBigdata\\f1\\results.csv')
# Step 2: Handle missing values
df.replace('\\N', np.nan, inplace=True)

# Step 3: Convert relevant columns to numeric
numeric_columns = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Step 4: Handle missing values in the 'rank' column
median_rank = df['rank'].median()
df['rank'].fillna(median_rank, inplace=True)

# Step 5: Handle outliers (optional)
Q1 = df['position'].quantile(0.25)
Q3 = df['position'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
df = df[df['position'] <= upper_bound]

# Step 6: Feature Engineering (optional)
df['race_length'] = df['laps'] * df['milliseconds']

# Step 7: Create meaningful visualizations

# Scatter Plot: Relationship between 'position' and 'race_length'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='position', y='race_length', data=df)
plt.title("Scatter Plot: Position vs. Race Length")
plt.xlabel("Position")
plt.ylabel("Race Length")
plt.show()

# Heatmap: Correlation between numeric features
numeric_features = ['raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionOrder', 'points', 'laps', 'milliseconds', 'fastestLap', 'rank', 'fastestLapSpeed', 'statusId', 'race_length']
correlation_matrix = df[numeric_features].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Heatmap: Correlation between Numeric Features")
plt.show()

# Bar Chart: Number of drivers by constructor
plt.figure(figsize=(12, 6))
driver_count_by_constructor = df.groupby('constructorId')['driverId'].nunique().reset_index()
sns.barplot(x='constructorId', y='driverId', data=driver_count_by_constructor)
plt.title("Number of Drivers by Constructor")
plt.xlabel("Constructor ID")
plt.ylabel("Number of Drivers")
plt.show()

# Bar Chart: Distribution of positions
plt.figure(figsize=(10, 6))
sns.countplot(x='position', data=df)
plt.title("Distribution of Positions")
plt.xlabel("Position")
plt.ylabel("Count")
plt.show()

# Bar Chart: Distribution of statusId
plt.figure(figsize=(10, 6))
sns.countplot(x='statusId', data=df)
plt.title("Distribution of Status ID")
plt.xlabel("Status ID")
plt.ylabel("Count")
plt.show()"""
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26080 entries, 0 to 26079
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         26080 non-null  int64
#  1   raceId           26080 non-null  int64
#  2   driverId         26080 non-null  int64
#  3   constructorId    26080 non-null  int64
#  4   number           26080 non-null  object
#  5   grid             26080 non-null  int64
#  6   position         26080 non-null  object
#  7   positionText     26080 non-null  object
#  8   positionOrder    26080 non-null  int64
#  9   points           26080 non-null  float64
#  10  laps             26080 non-null  int64
#  11  time             26080 non-null  object
#  12  milliseconds     26080 non-null  object
#  13  fastestLap       26080 non-null  object
#  14  rank             26080 non-null  object
#  15  fastestLapTime   26080 non-null  object
# ...
